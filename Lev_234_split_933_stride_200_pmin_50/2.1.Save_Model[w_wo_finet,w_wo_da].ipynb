# %% [markdown]
# ## 2. Load Data and Train a model then save the model's weight
#
# **Used Hyperparameter**<br>
# Without Data Augmentation<br>
#
#
# -----------------------<br>
# Level: 2,3,4 images <br>
# Number of train,val,test: 9, 3, 3 <br>
# train's stride : 200 <br>
# test's stride: 299 <br>
# tissue percent min: 50 <br>

# %%
import numpy as np
import os
from PIL import Image
import pathlib
from skimage.color import rgb2gray
from sklearn.model_selection import train_test_split
from itertools import chain
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, Input, GlobalAveragePooling2D, concatenate, BatchNormalization, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from matplotlib.patches import Rectangle
import re
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline

# %%
import os

# Initialization
lowest_level = 2
highest_level = 4
train_val_stride = 200
test_stride = 299
tissue_p_min = 50

dir = '/content/drive/MyDrive/Applied_Deep_Learning_Project/'
current_dir = 'Lev_234_split_933_stride_200_pmin_50'
saving_dir = os.path.join(dir,current_dir)
saving_dir
# Out:
# '/content/drive/MyDrive/Applied_Deep_Learning_Project/save_data_234_downsample/'

# %%
# Mount drive
from google.colab import drive 
drive.mount('/content/drive', force_remount=True)
print()

# Check TensorFlow version
import tensorflow as tf 
print("TF version: ", tf.__version__)
print()

# Check which GPU with available RAM
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

# !nvidia-smi --query-gpu=gpu_name,driver_version,memory.total --format=csv
# Out:
# Mounted at /content/drive
#
# TF version:  2.4.0
#
# Found GPU at: /device:GPU:0
# name, driver_version, memory.total [MiB]
# Tesla V100-SXM2-16GB, 418.67, 16130 MiB

# %%
zoom1_train = np.load(os.path.join(saving_dir,'zoom1_train.npy'))
zoom2_train = np.load(os.path.join(saving_dir,'zoom2_train.npy'))
zoom3_train = np.load(os.path.join(saving_dir,'zoom3_train.npy'))
label_train = np.load(os.path.join(saving_dir,'label_train.npy'))

zoom1_valid = np.load(os.path.join(saving_dir,'zoom1_valid.npy'))
zoom2_valid = np.load(os.path.join(saving_dir,'zoom2_valid.npy'))
zoom3_valid = np.load(os.path.join(saving_dir,'zoom3_valid.npy'))
label_valid = np.load(os.path.join(saving_dir,'label_valid.npy'))

X_train = [zoom1_train, zoom2_train, zoom3_train]
X_valid = [zoom1_valid, zoom2_valid, zoom3_valid]
BATCH_SIZE = 32

# %%
def create_inceptionv3(weights='imagenet',include_top = False, input_shape = (299,299,3)):
  base_model = tf.keras.applications.InceptionV3(weights=weights,include_top = include_top, input_shape = input_shape)
  base_model.trainable = False
  return base_model


def create_inceptionv3_fine_tune(weights='imagenet',include_top = False, input_shape = (299,299,3)):
  base_model = tf.keras.applications.InceptionV3(weights=weights,include_top = include_top, input_shape = input_shape)
  
  base_model.trainable = True
  # Let's take a look to see how many layers are in the base model
  print("Number of layers in the base InceptionV3 model: ", len(base_model.layers))
  # Fine-tune from this layer onwards
  fine_tune_at = 100
  print("Start fine tuning at layer: ", fine_tune_at)

  # Freeze all the layers before the `fine_tune_at` layer
  for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False

  return base_model


def create_global_avg_layer():
  return tf.keras.layers.GlobalAveragePooling2D()


def create_dense_layer():
  return tf.keras.layers.Dense(1024, activation='relu')

# %%
# Reference used to put multiple inputs
# # https://www.pyimagesearch.com/2019/02/04/keras-multiple-inputs-and-mixed-data/

def create_model_keras_inputs_two(fine_tune):

  if fine_tune:
    base_model_1 = create_inceptionv3_fine_tune()
    base_model_2 = create_inceptionv3_fine_tune()
    base_model_3 = create_inceptionv3_fine_tune()
  
  else: 
    base_model_1 = create_inceptionv3()
    base_model_2 = create_inceptionv3()
    base_model_3 = create_inceptionv3()

  global_avg_layer = create_global_avg_layer()
  dense_layer = create_dense_layer()

  model_1 = tf.keras.Sequential([
    base_model_1,
    global_avg_layer,
    dense_layer,
    #prediction_layer
  ])

  model_2 = tf.keras.Sequential([
    base_model_2,
    global_avg_layer,
    dense_layer,
    #prediction_layer
  ])

  model_3 = tf.keras.Sequential([
    base_model_3,
    global_avg_layer,
    dense_layer,
    #prediction_layer
  ])

  input1 = Input(shape=(299,299,3))
  input2 = Input(shape=(299,299,3))
  input3 = Input(shape=(299,299,3))
    
  model_concat = concatenate([model_1(input1) ,model_2(input2),model_3(input3)])
  model = Dense(1024, activation='relu')(model_concat)
  model = Dense(1, activation='sigmoid')(model)
  model_final = Model(inputs=[input1,input2,input3],outputs=model)

  return model_final

# %%
# A plotting function you can reuse
def plot(history):
  # The history object contains results on the training and test
  # sets for each epoch
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  # Get the number of epochs
  epochs = range(len(acc))

  # added new version for better layout in visualization (for fun)
  fig, ax = plt.subplots(1,2, figsize = (14,5))
  ax[0].set_title('Training and validation accuracy')
  ax[0].plot(epochs, acc, color='blue', label='Train')
  ax[0].plot(epochs, val_acc, color='orange', label='Val')
  ax[0].set_xlabel('Epoch')
  ax[0].set_ylabel('Accuracy')
  ax[0].legend()

  ax[1].set_title('Training and validation loss')
  ax[1].plot(epochs, loss, color='blue', label='Train')
  ax[1].plot(epochs, val_loss, color='orange', label='Val')
  ax[1].set_xlabel('Epoch')
  ax[1].set_ylabel('Loss')
  ax[1].legend()

# %% [markdown]
# ### Version a: <br>
# #### A model train with 9 train, 3 val [per image]
# #### model **without** fine tuning and **without** data augmentation

# %%
mdl_9_3_wo_ft_wo_da = create_model_keras_inputs_two(fine_tune = False)
mdl_9_3_wo_ft_wo_da.summary()
display(plot_model(mdl_9_3_wo_ft_wo_da))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 1024)         23900960    input_9[0][0]
# __________________________________________________________________________________________________
# sequential_4 (Sequential)       (None, 1024)         23900960    input_10[0][0]
# __________________________________________________________________________________________________
# sequential_5 (Sequential)       (None, 1024)         23900960    input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 3072)         0           sequential_3[0][0]
#                                                                  sequential_4[0][0]
#                                                                  sequential_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         3146752     concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            1025        dense_2[0][0]
# ==================================================================================================
# Total params: 70,654,305
# Trainable params: 5,245,953
# Non-trainable params: 65,408,352
# __________________________________________________________________________________________________

# %%
mdl_9_3_wo_ft_wo_da.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

plot(mdl_9_3_wo_ft_wo_da.fit(X_train,label_train, batch_size=BATCH_SIZE,
                             validation_data =(X_valid, label_valid),  epochs=10))
# Out:
# Epoch 1/10
# 184/184 [==============================] - 38s 154ms/step - loss: 0.3359 - accuracy: 0.8854 - val_loss: 1.2221 - val_accuracy: 0.5785
# Epoch 2/10
# 184/184 [==============================] - 25s 134ms/step - loss: 0.1985 - accuracy: 0.9169 - val_loss: 0.9094 - val_accuracy: 0.6077
# Epoch 3/10
# 184/184 [==============================] - 25s 134ms/step - loss: 0.2108 - accuracy: 0.9157 - val_loss: 0.7884 - val_accuracy: 0.6649
# Epoch 4/10
# 184/184 [==============================] - 25s 134ms/step - loss: 0.1733 - accuracy: 0.9337 - val_loss: 1.2568 - val_accuracy: 0.6144
# Epoch 5/10
# 184/184 [==============================] - 25s 134ms/step - loss: 0.1464 - accuracy: 0.9457 - val_loss: 2.2114 - val_accuracy: 0.6024
# Epoch 6/10
# 184/184 [==============================] - 25s 134ms/step - loss: 0.1415 - accuracy: 0.9441 - val_loss: 1.0376 - val_accuracy: 0.5705
# Epoch 7/10
# 184/184 [==============================] - 25s 134ms/step - loss: 0.1482 - accuracy: 0.9475 - val_loss: 1.1927 - val_accuracy: 0.6277
# Epoch 8/10
# 184/184 [==============================] - 25s 134ms/step - loss: 0.1061 - accuracy: 0.9594 - val_loss: 1.0448 - val_accuracy: 0.6569
# Epoch 9/10
# 184/184 [==============================] - 25s 134ms/step - loss: 0.1080 - accuracy: 0.9585 - val_loss: 1.1590 - val_accuracy: 0.6356
# Epoch 10/10
# 184/184 [==============================] - 25s 134ms/step - loss: 0.0947 - accuracy: 0.9623 - val_loss: 1.4727 - val_accuracy: 0.6184

# %%
#save_weights
mdl_9_3_wo_ft_wo_da.save_weights(os.path.join(saving_dir,"mdl_9_3_wo_ft_wo_da.h5/"))

del mdl_9_3_wo_ft_wo_da

# %% [markdown]
# ### Version b: <br>
# #### A model train with 9 train, 3 val [per image]
# #### model **with** fine tuning and **without** data augmentation

# %%
mdl_9_3_w_ft_wo_da = create_model_keras_inputs_two(fine_tune = True)
mdl_9_3_w_ft_wo_da.summary()
# display(plot_model(mdl_9_3_w_ft_wo_da))
# Out:
# Number of layers in the base InceptionV3 model:  311
# Start fine tuning at layer:  100
# Number of layers in the base InceptionV3 model:  311
# Start fine tuning at layer:  100
# Number of layers in the base InceptionV3 model:  311
# Start fine tuning at layer:  100
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# sequential_6 (Sequential)       (None, 1024)         23900960    input_15[0][0]
# __________________________________________________________________________________________________
# sequential_7 (Sequential)       (None, 1024)         23900960    input_16[0][0]
# __________________________________________________________________________________________________
# sequential_8 (Sequential)       (None, 1024)         23900960    input_17[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 3072)         0           sequential_6[0][0]
#                                                                  sequential_7[0][0]
#                                                                  sequential_8[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1024)         3146752     concatenate_19[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            1025        dense_5[0][0]
# ==================================================================================================
# Total params: 70,654,305
# Trainable params: 64,125,057
# Non-trainable params: 6,529,248
# __________________________________________________________________________________________________

# %%
mdl_9_3_w_ft_wo_da.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

plot(mdl_9_3_w_ft_wo_da.fit(X_train,label_train, batch_size=BATCH_SIZE, 
                             validation_data =(X_valid, label_valid),  epochs=10))
# Out:
# Epoch 1/10
# 184/184 [==============================] - 71s 300ms/step - loss: 0.5211 - accuracy: 0.8403 - val_loss: 102.7551 - val_accuracy: 0.5000
# Epoch 2/10
# 184/184 [==============================] - 52s 280ms/step - loss: 0.1983 - accuracy: 0.9327 - val_loss: 7.5057 - val_accuracy: 0.4854
# Epoch 3/10
# 184/184 [==============================] - 52s 280ms/step - loss: 0.1841 - accuracy: 0.9360 - val_loss: 1.2058 - val_accuracy: 0.5386
# Epoch 4/10
# 184/184 [==============================] - 52s 280ms/step - loss: 0.1056 - accuracy: 0.9658 - val_loss: 1.4273 - val_accuracy: 0.7234
# Epoch 5/10
# 184/184 [==============================] - 51s 280ms/step - loss: 0.0877 - accuracy: 0.9698 - val_loss: 3.2083 - val_accuracy: 0.5372
# Epoch 6/10
# 184/184 [==============================] - 51s 280ms/step - loss: 0.0679 - accuracy: 0.9804 - val_loss: 1.7457 - val_accuracy: 0.6729
# Epoch 7/10
# 184/184 [==============================] - 51s 280ms/step - loss: 0.0992 - accuracy: 0.9652 - val_loss: 2.7680 - val_accuracy: 0.6290
# Epoch 8/10
# 184/184 [==============================] - 51s 280ms/step - loss: 0.0702 - accuracy: 0.9775 - val_loss: 2.0264 - val_accuracy: 0.6170
# Epoch 9/10
# 184/184 [==============================] - 51s 280ms/step - loss: 0.0558 - accuracy: 0.9793 - val_loss: 2.0488 - val_accuracy: 0.5718
# Epoch 10/10
# 184/184 [==============================] - 51s 279ms/step - loss: 0.0747 - accuracy: 0.9756 - val_loss: 2.1457 - val_accuracy: 0.6223

# %%
#save_weights
mdl_9_3_w_ft_wo_da.save_weights(os.path.join(saving_dir,"mdl_9_3_w_ft_wo_da.h5/"))

del mdl_9_3_w_ft_wo_da

# %% [markdown]
# ### Version c: <br>
# #### A model train with 9 train, 3 val [per image]
# #### model **without** fine tuning and **with** data augmentation

# %%
# Reference used to take multiple inputs for ImageData Geneartor
# https://stackoverflow.com/questions/49404993/keras-how-to-use-fit-generator-with-multiple-inputs

gen = ImageDataGenerator(
    rotation_range=90,
    shear_range=0.2)
    # horizontal_flip = True,
    # vertical_flip = True)

gen_valid = ImageDataGenerator()

def generator_two_img(X1, X2, X3, y, batch_size):
    genX1 = gen.flow(X1, y,  batch_size=batch_size, seed=1)
    genX2 = gen.flow(X2, y, batch_size=batch_size, seed=1)
    genX3 = gen.flow(X3, y, batch_size=batch_size, seed=1)
    while True:
        X1i = genX1.next()
        X2i = genX2.next()
        X3i = genX3.next()
        yield [X1i[0], X2i[0], X3i[0]], X1i[1]

def generator_two_img_valid(X1, X2, y, batch_size):
    genX1 = gen_valid.flow(X1, y,  batch_size=batch_size, seed=1)
    genX2 = gen_valid.flow(X2, y, batch_size=batch_size, seed=1)
    while True:
        X1i = genX1.next()
        X2i = genX2.next()
        yield [X1i[0], X2i[0]], X1i[1]

X_train_ = generator_two_img(zoom1_train, zoom2_train, zoom3_train, label_train, 32)
X_valid_ = generator_two_img_valid(zoom1_valid, zoom2_valid, label_valid, 32)
BATCH_SIZE = 32

# %%
mdl_9_3_wo_ft_w_da = create_model_keras_inputs_two(fine_tune = False)
mdl_9_3_wo_ft_w_da.summary()
# display(plot_model(mdl_9_3_wo_ft_w_da))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 1024)         23900960    input_4[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1024)         23900960    input_5[0][0]
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 1024)         23900960    input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 3072)         0           sequential[0][0]
#                                                                  sequential_1[0][0]
#                                                                  sequential_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         3146752     concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            1025        dense_1[0][0]
# ==================================================================================================
# Total params: 70,654,305
# Trainable params: 5,245,953
# Non-trainable params: 65,408,352
# __________________________________________________________________________________________________

# %%
mdl_9_3_wo_ft_w_da.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

plot(mdl_9_3_wo_ft_w_da.fit(X_train_, batch_size=BATCH_SIZE, 
                            steps_per_epoch = len(zoom1_train)/BATCH_SIZE,
                            validation_data = ([zoom1_valid,zoom2_valid,zoom3_valid],label_valid), validation_steps = len(zoom1_valid)/BATCH_SIZE,
                            shuffle=False, epochs=15))
# Out:
# Epoch 1/15

# %%
#save_weights
mdl_9_3_wo_ft_w_da.save_weights(os.path.join(saving_dir,"mdl_9_3_wo_ft_w_da.h5/"))

del mdl_9_3_wo_ft_w_da

# %% [markdown]
# ### Version d: <br>
# #### A model train with 9 train, 3 val [per image]
# #### model **with** fine tuning and **with** data augmentation

# %%
mdl_9_3_w_ft_w_da = create_model_keras_inputs_two(fine_tune = True)
mdl_9_3_w_ft_w_da.summary()
# display(plot_model(mdl_9_3_w_ft_w_da))
# Out:
# Number of layers in the base InceptionV3 model:  311
# Start fine tuning at layer:  100
# Number of layers in the base InceptionV3 model:  311
# Start fine tuning at layer:  100
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# sequential_6 (Sequential)       (None, 1024)         23900960    input_15[0][0]
# __________________________________________________________________________________________________
# sequential_7 (Sequential)       (None, 1024)         23900960    input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 2048)         0           sequential_6[0][0]
#                                                                  sequential_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1024)         2098176     concatenate_19[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            1025        dense_10[0][0]
# ==================================================================================================
# Total params: 47,802,945
# Trainable params: 43,450,113
# Non-trainable params: 4,352,832
# __________________________________________________________________________________________________

# %%
mdl_9_3_w_ft_w_da.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

plot(mdl_9_3_w_ft_w_da.fit(X_train_, batch_size=BATCH_SIZE, 
                steps_per_epoch = len(zoom1_train)/BATCH_SIZE,
                validation_data =X_valid_, validation_steps = len(zoom1_valid)/BATCH_SIZE, 
                shuffle=False, epochs=15))
# Out:
# Epoch 1/15
# 172/172 [==============================] - 189s 1s/step - loss: 0.5253 - accuracy: 0.7833 - val_loss: 2.4569 - val_accuracy: 0.4259
# Epoch 2/15
# 172/172 [==============================] - 178s 1s/step - loss: 0.2366 - accuracy: 0.9195 - val_loss: 10.1804 - val_accuracy: 0.4966
# Epoch 3/15
# 172/172 [==============================] - 178s 1s/step - loss: 0.1724 - accuracy: 0.9322 - val_loss: 3.3666 - val_accuracy: 0.4983
# Epoch 4/15
# 172/172 [==============================] - 178s 1s/step - loss: 0.1551 - accuracy: 0.9448 - val_loss: 1.4231 - val_accuracy: 0.5500
# Epoch 5/15
# 172/172 [==============================] - 177s 1s/step - loss: 0.1342 - accuracy: 0.9479 - val_loss: 3.9771 - val_accuracy: 0.4862
# Epoch 6/15
# 172/172 [==============================] - 177s 1s/step - loss: 0.1675 - accuracy: 0.9496 - val_loss: 1.3661 - val_accuracy: 0.5603
# Epoch 7/15
# 172/172 [==============================] - 178s 1s/step - loss: 0.1046 - accuracy: 0.9641 - val_loss: 1.9574 - val_accuracy: 0.5466
# Epoch 8/15
# 172/172 [==============================] - 177s 1s/step - loss: 0.1231 - accuracy: 0.9571 - val_loss: 5.7666 - val_accuracy: 0.4931
# Epoch 9/15
# 172/172 [==============================] - 177s 1s/step - loss: 0.1065 - accuracy: 0.9630 - val_loss: 2.7625 - val_accuracy: 0.5466
# Epoch 10/15
# 172/172 [==============================] - 178s 1s/step - loss: 0.1064 - accuracy: 0.9594 - val_loss: 1.1107 - val_accuracy: 0.6138
# Epoch 11/15
# 172/172 [==============================] - 177s 1s/step - loss: 0.1051 - accuracy: 0.9630 - val_loss: 0.9466 - val_accuracy: 0.6741
# Epoch 12/15
# 172/172 [==============================] - 176s 1s/step - loss: 0.1169 - accuracy: 0.9578 - val_loss: 3.1433 - val_accuracy: 0.5000
# Epoch 13/15
# 172/172 [==============================] - 176s 1s/step - loss: 0.1041 - accuracy: 0.9632 - val_loss: 1.3768 - val_accuracy: 0.4414
# Epoch 14/15
# 172/172 [==============================] - 176s 1s/step - loss: 0.0973 - accuracy: 0.9667 - val_loss: 1.0577 - val_accuracy: 0.6190
# Epoch 15/15
# 172/172 [==============================] - 176s 1s/step - loss: 0.1068 - accuracy: 0.9639 - val_loss: 2.0197 - val_accuracy: 0.5000

# %%
#save_weights
mdl_9_3_w_ft_w_da.save_weights(os.path.join(saving_dir,"mdl_9_3_w_ft_w_da.h5/"))

del mdl_9_3_w_ft_w_da
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-fd310ff99d5c> in <module>()
#       1 #save_weights
# ----> 2 mdl_9_3_w_ft_w_da.save_weights(os.path.join(saving_dir,"mdl_9_3_w_ft_w_da.h5/"))
#       3
#       4 del mdl_9_3_w_ft_w_da
#
# NameError: name 'mdl_9_3_w_ft_w_da' is not defined

# %%
# # Reference used to put multiple inputs
# # https://www.pyimagesearch.com/2019/02/04/keras-multiple-inputs-and-mixed-data/

# def create_model_keras_inputs_two_updated(fine_tune):

#   if fine_tune:
#     base_model_1 = create_inceptionv3_fine_tune()
#     base_model_2 = create_inceptionv3_fine_tune()
  
#   else: 
#     base_model_1 = create_inceptionv3()
#     base_model_2 = create_inceptionv3()

#   global_avg_layer = create_global_avg_layer()
#   dense_layer = create_dense_layer()
#   batch_norm_layer = create_batch_normalization()

#   model_1 = tf.keras.Sequential([
#     base_model_1,
#     global_avg_layer,
#     dense_layer,
#     #prediction_layer
#   ])

#   model_2 = tf.keras.Sequential([
#     base_model_2,
#     global_avg_layer,
#     dense_layer,
#     #prediction_layer
#   ])

#   input1 = Input(shape=(299,299,3))
#   input2 = Input(shape=(299,299,3))
    
#   model = concatenate([model_1(input1) ,model_2(input2)], axis =1)
  
#   model = tf.keras.layers.BatchNormalization()(model)
#   model = tf.keras.layers.Dropout(0.3)(model)
#   model = Dense(1024, activation='relu')(model)
  
#   model = tf.keras.layers.BatchNormalization()(model)
#   model = tf.keras.layers.Dropout(0.3)(model)
#   model = Dense(128, activation='relu')(model)
  
#   model = tf.keras.layers.BatchNormalization()(model)
#   model = tf.keras.layers.Dropout(0.3)(model)
#   model = Dense(1, activation='sigmoid')(model)

#   model_final = Model(inputs=[input1,input2],outputs=model)

#   return model_final

# %% [markdown]
# ### Version 2.a: Batch Normalization <br>
# #### A model train with 9 train, 3 val [per image]
# #### model **without** fine tuning and **without** data augmentation
# #### **Also** added Batch Normalization and extra dense layer

# %%
def add_layers(model, add_BN, add_Dropout):
  if add_BN:
    if add_Dropout:
      print("Added BN and Dropout")
      model = tf.keras.layers.BatchNormalization()(model)
      model = tf.keras.layers.Dropout(0.3)(model)
      model = Dense(1024, activation='relu')(model)
      model = tf.keras.layers.BatchNormalization()(model)
      model = tf.keras.layers.Dropout(0.3)(model)
      model = Dense(128, activation='relu')(model)
      model = tf.keras.layers.BatchNormalization()(model)
      model = tf.keras.layers.Dropout(0.3)(model)
      model = Dense(1, activation='sigmoid')(model)
      return model
    
    else: # i.e. only add Batch Normalization
      print("Added only BN")
      model = tf.keras.layers.BatchNormalization()(model)
      model = Dense(1024, activation='relu')(model)
      model = tf.keras.layers.BatchNormalization()(model)
      model = Dense(128, activation='relu')(model)
      model = tf.keras.layers.BatchNormalization()(model)
      model = Dense(1, activation='sigmoid')(model)
      return model

    
  else: # i.e. only apply Dropout
    print("Added only Dropout")
    model = tf.keras.layers.Dropout(0.3)(model)
    model = Dense(1024, activation='relu')(model)
    model = tf.keras.layers.Dropout(0.3)(model)
    model = Dense(128, activation='relu')(model)
    model = tf.keras.layers.Dropout(0.3)(model)
    model = Dense(1, activation='sigmoid')(model)
    return model

# %%
# Reference used to put multiple inputs
# https://www.pyimagesearch.com/2019/02/04/keras-multiple-inputs-and-mixed-data/

def create_model_keras_inputs_two_updated(fine_tune, add_BN, add_Dropout):

  if fine_tune:
    base_model_1 = create_inceptionv3_fine_tune()
    base_model_2 = create_inceptionv3_fine_tune()
    base_model_3 = create_inceptionv3_fine_tune()
  
  else: 
    base_model_1 = create_inceptionv3()
    base_model_2 = create_inceptionv3()
    base_model_3 = create_inceptionv3()

  global_avg_layer = create_global_avg_layer()
  dense_layer = create_dense_layer()

  model_1 = tf.keras.Sequential([
    base_model_1,
    global_avg_layer,
    dense_layer,
    #prediction_layer
  ])

  model_2 = tf.keras.Sequential([
    base_model_2,
    global_avg_layer,
    dense_layer,
    #prediction_layer
  ])

  model_3 = tf.keras.Sequential([
    base_model_3,
    global_avg_layer,
    dense_layer,
    #prediction_layer
  ])

  input1 = Input(shape=(299,299,3))
  input2 = Input(shape=(299,299,3))
  input3 = Input(shape=(299,299,3))
    
  model = concatenate([model_1(input1) ,model_2(input2) ,model_3(input3)], axis =1)
  model = add_layers(model = model, add_BN = add_BN, add_Dropout = add_Dropout)
  model_final = Model(inputs=[input1,input2,input3],outputs=model)

  return model_final

# %%
mdl_9_3_wo_ft_wo_da_BN = create_model_keras_inputs_two_updated(fine_tune = False, add_BN = True, add_Dropout = False)
mdl_9_3_wo_ft_wo_da_BN.summary()
display(plot_model(mdl_9_3_wo_ft_wo_da_BN))
# Out:
# Added only BN
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 1024)         23900960    input_4[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1024)         23900960    input_5[0][0]
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 1024)         23900960    input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 3072)         0           sequential[0][0]
#                                                                  sequential_1[0][0]
#                                                                  sequential_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 3072)         12288       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         3146752     batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 1024)         4096        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          131200      batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 128)          512         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            129         batch_normalization_284[0][0]
# ==================================================================================================
# Total params: 70,801,505
# Trainable params: 5,384,705
# Non-trainable params: 65,416,800
# __________________________________________________________________________________________________

# %%
mdl_9_3_wo_ft_wo_da_BN.compile(optimizer=Adam(learning_rate=0.0005),loss='binary_crossentropy',metrics=['accuracy'])

plot(mdl_9_3_wo_ft_wo_da_BN.fit(X_train,label_train, 
                batch_size=BATCH_SIZE, 
                validation_data =(X_valid, label_valid),  epochs=10))
# Out:
# Epoch 1/10
# 184/184 [==============================] - 45s 159ms/step - loss: 0.3133 - accuracy: 0.8744 - val_loss: 2.2212 - val_accuracy: 0.5652
# Epoch 2/10
# 184/184 [==============================] - 25s 135ms/step - loss: 0.1883 - accuracy: 0.9252 - val_loss: 1.4698 - val_accuracy: 0.5904
# Epoch 3/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.1721 - accuracy: 0.9312 - val_loss: 1.1294 - val_accuracy: 0.6423
# Epoch 4/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.1413 - accuracy: 0.9449 - val_loss: 1.2913 - val_accuracy: 0.5785
# Epoch 5/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.1285 - accuracy: 0.9513 - val_loss: 2.4932 - val_accuracy: 0.4894
# Epoch 6/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.1277 - accuracy: 0.9545 - val_loss: 1.0111 - val_accuracy: 0.6782
# Epoch 7/10
# 184/184 [==============================] - 25s 137ms/step - loss: 0.1087 - accuracy: 0.9619 - val_loss: 1.6667 - val_accuracy: 0.6809
# Epoch 8/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.1024 - accuracy: 0.9595 - val_loss: 1.3002 - val_accuracy: 0.6582
# Epoch 9/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.0887 - accuracy: 0.9658 - val_loss: 1.1124 - val_accuracy: 0.6742
# Epoch 10/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.0781 - accuracy: 0.9724 - val_loss: 1.3829 - val_accuracy: 0.6556

# %%
#save_weights
mdl_9_3_wo_ft_wo_da_BN.save_weights(os.path.join(saving_dir,"mdl_9_3_wo_ft_wo_da_BN.h5/"))

del mdl_9_3_wo_ft_wo_da_BN

# %% [markdown]
# ### Version 2.b: Dropout <br>
# #### A model train with 9 train, 3 val [per image]
# #### model **without** fine tuning and **without** data augmentation
# #### **Also** added Dropout and extra dense layer

# %%
mdl_9_3_wo_ft_wo_da_Dropout = create_model_keras_inputs_two_updated(fine_tune = False, add_BN = False, add_Dropout = True)
mdl_9_3_wo_ft_wo_da_Dropout.summary()
display(plot_model(mdl_9_3_wo_ft_wo_da_Dropout))
# Out:
# Added only Dropout
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 1024)         23900960    input_10[0][0]
# __________________________________________________________________________________________________
# sequential_4 (Sequential)       (None, 1024)         23900960    input_11[0][0]
# __________________________________________________________________________________________________
# sequential_5 (Sequential)       (None, 1024)         23900960    input_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 3072)         0           sequential_3[0][0]
#                                                                  sequential_4[0][0]
#                                                                  sequential_5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 3072)         0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1024)         3146752     dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          131200      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            129         dropout_2[0][0]
# ==================================================================================================
# Total params: 70,784,609
# Trainable params: 5,376,257
# Non-trainable params: 65,408,352
# __________________________________________________________________________________________________

# %%
mdl_9_3_wo_ft_wo_da_Dropout.compile(optimizer=Adam(learning_rate=0.0005),loss='binary_crossentropy',metrics=['accuracy'])


plot(mdl_9_3_wo_ft_wo_da_Dropout.fit(X_train,label_train, 
                batch_size=BATCH_SIZE, 
                validation_data =(X_valid, label_valid),  epochs=10))
# Out:
# Epoch 1/10
# 184/184 [==============================] - 40s 154ms/step - loss: 2.5389 - accuracy: 0.7479 - val_loss: 0.8484 - val_accuracy: 0.6330
# Epoch 2/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.3284 - accuracy: 0.8694 - val_loss: 0.6233 - val_accuracy: 0.6676
# Epoch 3/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.2947 - accuracy: 0.8824 - val_loss: 0.8442 - val_accuracy: 0.6383
# Epoch 4/10
# 184/184 [==============================] - 25s 135ms/step - loss: 0.2632 - accuracy: 0.8928 - val_loss: 0.8898 - val_accuracy: 0.6569
# Epoch 5/10
# 184/184 [==============================] - 25s 135ms/step - loss: 0.2356 - accuracy: 0.9004 - val_loss: 1.1241 - val_accuracy: 0.6077
# Epoch 6/10
# 184/184 [==============================] - 25s 135ms/step - loss: 0.2071 - accuracy: 0.9151 - val_loss: 1.0339 - val_accuracy: 0.6609
# Epoch 7/10
# 184/184 [==============================] - 25s 135ms/step - loss: 0.2056 - accuracy: 0.9162 - val_loss: 1.2600 - val_accuracy: 0.6250
# Epoch 8/10
# 184/184 [==============================] - 25s 135ms/step - loss: 0.2028 - accuracy: 0.9211 - val_loss: 1.3451 - val_accuracy: 0.6303
# Epoch 9/10
# 184/184 [==============================] - 25s 135ms/step - loss: 0.1980 - accuracy: 0.9212 - val_loss: 1.3002 - val_accuracy: 0.5997
# Epoch 10/10
# 184/184 [==============================] - 25s 135ms/step - loss: 0.1722 - accuracy: 0.9317 - val_loss: 1.0601 - val_accuracy: 0.6503

# %%
#save_weights
mdl_9_3_wo_ft_wo_da_Dropout.save_weights(os.path.join(saving_dir,"mdl_9_3_wo_ft_wo_da_Dropout.h5/"))

del mdl_9_3_wo_ft_wo_da_Dropout

# %% [markdown]
# ### Version 2.c: Batch Norm + Dropout <br>
# #### A model train with 9 train, 3 val [per image]
# #### model **without** fine tuning and **without** data augmentation
# #### **Also** added Batch Normailzation, Dropout, and extra dense layer

# %%
mdl_9_3_wo_ft_wo_da_BN_DO = create_model_keras_inputs_two_updated(fine_tune = False, add_BN = True, add_Dropout = True)
mdl_9_3_wo_ft_wo_da_BN_DO.summary()
display(plot_model(mdl_9_3_wo_ft_wo_da_BN_DO))
# Out:
# Added BN and Dropout
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# sequential_6 (Sequential)       (None, 1024)         23900960    input_16[0][0]
# __________________________________________________________________________________________________
# sequential_7 (Sequential)       (None, 1024)         23900960    input_17[0][0]
# __________________________________________________________________________________________________
# sequential_8 (Sequential)       (None, 1024)         23900960    input_18[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 3072)         0           sequential_6[0][0]
#                                                                  sequential_7[0][0]
#                                                                  sequential_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_849 (BatchN (None, 3072)         12288       concatenate_20[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 3072)         0           batch_normalization_849[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1024)         3146752     dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_850 (BatchN (None, 1024)         4096        dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           batch_normalization_850[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          131200      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_851 (BatchN (None, 128)          512         dense_10[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 128)          0           batch_normalization_851[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            129         dropout_5[0][0]
# ==================================================================================================
# Total params: 70,801,505
# Trainable params: 5,384,705
# Non-trainable params: 65,416,800
# __________________________________________________________________________________________________

# %%
mdl_9_3_wo_ft_wo_da_BN_DO.compile(optimizer=Adam(learning_rate=0.0005),loss='binary_crossentropy',metrics=['accuracy'])


plot(mdl_9_3_wo_ft_wo_da_BN_DO.fit(X_train,label_train, 
                batch_size=BATCH_SIZE, 
                validation_data =(X_valid, label_valid),  epochs=10))
# Out:
# Epoch 1/10
# 184/184 [==============================] - 41s 157ms/step - loss: 0.3463 - accuracy: 0.8548 - val_loss: 2.0337 - val_accuracy: 0.5638
# Epoch 2/10
# 184/184 [==============================] - 25s 137ms/step - loss: 0.2662 - accuracy: 0.8968 - val_loss: 1.9269 - val_accuracy: 0.4774
# Epoch 3/10
# 184/184 [==============================] - 25s 137ms/step - loss: 0.2271 - accuracy: 0.9119 - val_loss: 1.8181 - val_accuracy: 0.5253
# Epoch 4/10
# 184/184 [==============================] - 25s 137ms/step - loss: 0.1839 - accuracy: 0.9254 - val_loss: 1.1634 - val_accuracy: 0.6277
# Epoch 5/10
# 184/184 [==============================] - 25s 137ms/step - loss: 0.1700 - accuracy: 0.9349 - val_loss: 1.5647 - val_accuracy: 0.5452
# Epoch 6/10
# 184/184 [==============================] - 25s 137ms/step - loss: 0.1674 - accuracy: 0.9380 - val_loss: 1.0247 - val_accuracy: 0.6237
# Epoch 7/10
# 184/184 [==============================] - 25s 137ms/step - loss: 0.1614 - accuracy: 0.9369 - val_loss: 1.0908 - val_accuracy: 0.6503
# Epoch 8/10
# 184/184 [==============================] - 25s 137ms/step - loss: 0.1522 - accuracy: 0.9398 - val_loss: 1.0441 - val_accuracy: 0.6636
# Epoch 9/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.1520 - accuracy: 0.9435 - val_loss: 1.3684 - val_accuracy: 0.5532
# Epoch 10/10
# 184/184 [==============================] - 25s 136ms/step - loss: 0.1440 - accuracy: 0.9454 - val_loss: 1.2070 - val_accuracy: 0.6476

# %%
#save_weights
mdl_9_3_wo_ft_wo_da_BN_DO.save_weights(os.path.join(saving_dir,"mdl_9_3_wo_ft_wo_da_BN_DO.h5/"))

del mdl_9_3_wo_ft_wo_da_BN_DO
