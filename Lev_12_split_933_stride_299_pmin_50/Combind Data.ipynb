# %%
import numpy as np
import os

# %%
# Mount drive
from google.colab import drive 
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
dir = '/content/drive/MyDrive/Applied_Deep_Learning_Project/'
current_dir = 'Lev_12_split_933_stride_299_pmin_50'
saving_dir = os.path.join(dir,current_dir)
saving_dir
# Out:
# '/content/drive/MyDrive/Applied_Deep_Learning_Project/Lev_12_split_933_stride_299_pmin_50'

# %%
zoom1 = np.load(os.path.join(saving_dir,'zoom1_test_13' + '.npy'))
zoom2 = np.load(os.path.join(saving_dir,'zoom2_test_13' + '.npy'))

# %%
np.save(os.path.join(saving_dir,'zoom1_test_13_full.npy'),np.concatenate((np.load(os.path.join(saving_dir,'zoom1_test_13_1.npy')),np.load(os.path.join(saving_dir,'zoom1_test_13_2.npy'))),axis=0))

# %%
zoom2 = np.concatenate((np.load(os.path.join(saving_dir,'zoom2_test_13_1.npy')),np.load(os.path.join(saving_dir,'zoom2_test_13_2.npy'))),axis=0)

# %%
zoom2_1 = np.load(os.path.join(saving_dir,'zoom2_test_' + str(13) + '_1.npy'))
zoom2_2 = np.load(os.path.join(saving_dir,'zoom2_test_' + str(13) + '_2.npy'))

# %%
patches_num = np.load(os.path.join(saving_dir,'patches_num_test_13' + '.npy'))
patches_num

# %%
zoom2_1.shape
# Out:
# (15700, 299, 299, 3)

# %%
zoom2_2.shape
# Out:
# (13345, 299, 299, 3)

# %%
np.save(os.path.join(saving_dir,np.concatenate((zoom2_1, zoom2_2), axis=0)))

# %%
zoom2_1.shape
# Out:
# (172, 299, 299, 3)

# %%
zoom2_2.shape
# Out:
# (958, 299, 299, 3)

# %%
zoom2_1 = np.load(os.path.join(saving_dir,'zoom2_test_' + str(13) + '.npy'))

# %%
patches_num = np.load(os.path.join(saving_dir,'patches_num_test_13' + '.npy'))

# %%
patches_num
# Out:
# array([[29045,   157,   185]])

# %%
zoom2_1.shape
# Out:
# (7314, 299, 299, 3)

# %%
zoom2_1 = np.load(os.path.join(saving_dir,'zoom2_test_' + str(16) + '.npy'))

# %%
zoom2_1.shape
# Out:
# (436, 299, 299, 3)

# %%
patches_num = np.load(os.path.join(saving_dir,'patches_num_test_16' + '.npy'))

# %%
patches_num
# Out:
# array([[9078,  102,   89]])
