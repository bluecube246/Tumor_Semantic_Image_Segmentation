# %%
import os

# Initialization
lowest_level = 1
highest_level = 2
train_val_stride = 299
test_stride = 299
tissue_p_min = 50

dir = '/content/drive/MyDrive/Applied_Deep_Learning_Project/'
current_dir = 'Lev_12_split_933_stride_299_pmin_50'
saving_dir = os.path.join(dir,current_dir)
saving_dir
# Out:
# '/content/drive/MyDrive/Applied_Deep_Learning_Project/Lev_12_split_933_stride_299_pmin_50'

# %%
# Mount drive
from google.colab import drive 
drive.mount('/content/drive', force_remount=True)
print()
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
# zoom1_test_1 = np.load(os.path.join(saving_dir,'zoom1_test_11_1.npy'))

# %%
# zoom1_test_2 = np.load(os.path.join(saving_dir,'zoom1_test_11_2.npy'))

# %%
# zoom1_test_3 = np.load(os.path.join(saving_dir,'zoom1_test_11_3.npy'))

# %%
# zoom1_test_4 = np.load(os.path.join(saving_dir,'zoom1_test_11_4.npy'))

# %%
np.save(os.path.join(saving_dir,'zoom1_test_11.npy'),
          np.concatenate((np.load(os.path.join(saving_dir,'zoom1_test_11_1.npy')),
                             np.load(os.path.join(saving_dir,'zoom1_test_11_2.npy')),
                             np.load(os.path.join(saving_dir,'zoom1_test_11_3.npy')),
                             np.load(os.path.join(saving_dir,'zoom1_test_11_4.npy')) ),axis =0))

# %%
# zoom1_test_1 = np.load(os.path.join(saving_dir,'zoom1_test_11_1.npy'))
# zoom1_test_2 = np.load(os.path.join(saving_dir,'zoom1_test_11_2.npy'))
# zoom1_test_3 = np.load(os.path.join(saving_dir,'zoom1_test_11_3.npy'))
# zoom1_test_4 = np.load(os.path.join(saving_dir,'zoom1_test_11_4.npy'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7c3c429ee577> in <module>()
# ----> 1 zoom1_test_1 = np.load(os.path.join(saving_dir,'zoom1_test_11_1.npy'))
#       2 zoom1_test_2 = np.load(os.path.join(saving_dir,'zoom1_test_11_2.npy'))
#       3 zoom1_test_3 = np.load(os.path.join(saving_dir,'zoom1_test_11_3.npy'))
#       4 zoom1_test_4 = np.load(os.path.join(saving_dir,'zoom1_test_11_4.npy'))
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# ...

# %%
zoom2_test_1 = np.load(os.path.join(saving_dir,'zoom2_test_11_1.npy'))
zoom2_test_2 = np.load(os.path.join(saving_dir,'zoom2_test_11_2.npy'))
zoom2_test_3 = np.load(os.path.join(saving_dir,'zoom2_test_11_3.npy'))
zoom2_test_4 = np.load(os.path.join(saving_dir,'zoom2_test_11_4.npy'))

# %%
# label_train = np.load(os.path.join(saving_dir,'label_train.npy'))

# zoom1_valid = np.load(os.path.join(saving_dir,'zoom1_valid.npy'))
# zoom2_valid = np.load(os.path.join(saving_dir,'zoom2_valid.npy'))
# zoom3_valid = np.load(os.path.join(saving_dir,'zoom3_valid.npy'))
# label_valid = np.load(os.path.join(saving_dir,'label_valid.npy'))
